# %% [markdown]
# # BSAN391 -- Improving Search -- Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
def nonlinear_location(x,y):
    return ((60/(1+(x+1)**2+(y-3)**2))+(20/(1+(x-1)**2+(y-3)**2))+(30/(1+(x)**2+(y+4)**2)))

# %%
N = 5000
plt.rcParams['figure.figsize'] = (10,10)
x_values = np.linspace(-6, 6, N)
y_values = np.linspace(-7, 7, N)

# %%
X, Y = np.meshgrid(x_values, y_values)
Z = nonlinear_location(X, Y)

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 10)
manual_locations = [(-5, 0), (-3, 4), (-1, 4.5), (0, 3.5)]
ax.clabel(CS, inline=True, fontsize=9, manual=manual_locations, fmt='%1.1f')
plt.show()

# %%
#Interactive plot
#%matplotlib notebook
#fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot_surface(X, Y, Z)
plt.show()
